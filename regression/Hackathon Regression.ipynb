# %% [markdown]
# ---
# <a name = Section4></a>
# # Regression Hackathon
# ---

# %% [markdown]
# - In this hackathon, you need to predict car prices based on various features of a car. The goal is to develop accurate predictive models that can assist both buyers and sellers in determining fair market values for used cars.

# %% [markdown]
# | Column              | Description                                       |
# |---------------------|---------------------------------------------------|
# | Make                | Brand or manufacturer of the car                  |
# | Model               | Specific model of the car                         |
# | Price               | Price of the car (target variable)                |
# | Year                | Year of manufacture                               |
# | Kilometer           | Total kilometers driven                           |
# | Fuel Type           | Type of fuel used (e.g., petrol, diesel)         |
# | Transmission        | Type of transmission (e.g., manual, automatic)   |
# | Location            | Location where the car is being sold              |
# | Color               | Color of the car                                  |
# | Owner               | Number of previous owners                         |
# | Seller Type         | Type of seller (e.g., dealer, individual)        |
# | Engine              | Engine specifications (e.g., displacement)        |
# | Max Power           | Maximum power output of the engine                |
# | Max Torque          | Maximum torque output of the engine               |
# | Drivetrain          | Type of drivetrain (e.g., front-wheel drive, all-wheel drive) |
# | Length              | Length of the car                                 |
# | Width               | Width of the car                                  |
# | Height              | Height of the car                                 |
# | Seating Capacity    | Number of seats in the car                        |
# | Fuel Tank Capacity  | Capacity of the fuel tank                         |

# %%
import pandas as pd

# %%
data_link = "https://raw.githubusercontent.com/vasudevgupta31/datasets/master/regression/car_price_cardekho.csv"

# %%
data = pd.read_csv(data_link)
